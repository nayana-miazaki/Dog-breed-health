# %% [markdown]
# <a href="https://colab.research.google.com/github/nayana-miazaki/Dog-breed-health/blob/main/grafico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('medicao_vibracao.csv')

# %%
# Mapeamento de cores
cor_mapa = {
    'NORMAL': 'green',
    'ALERTA_Pre_falha': 'orange',
    'FALHA_CRITICA': 'red'
}
cores = df['Status'].map(cor_mapa)

# Gráfico de barras
plt.figure(figsize=(16, 6))
plt.bar(df['ID'], df['Aceleracao_Total'], color=cores, width=0.5)

plt.xlabel('Medições')
plt.ylabel('Aceleração Total')
plt.title('Aceleração por status ao longo das medições')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Legenda
import matplotlib.patches as mpatches
legenda = [mpatches.Patch(color=v, label=k) for k, v in cor_mapa.items()]
plt.legend(handles=legenda)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_temp = pd.read_csv('medicao_temperatura.csv')

# %%
# Mapeamento de cores
cor_mapa = {
    'NORMAL': 'green',
    'ALERTA_Pre_falha': 'orange',
    'FALHA_CRITICA': 'red'
}

cores = df_temp[' Status'].map(cor_mapa)

# Gráfico de barras
plt.figure(figsize=(16, 6))
plt.bar(df['ID'], df[' Temperatura'], color=cores, width=0.5)

plt.xlabel('Medições')
plt.ylabel('Temperatura')
plt.title('Temperatura por status ao longo das medições')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Legenda
import matplotlib.patches as mpatches
legenda = [mpatches.Patch(color=v, label=k) for k, v in cor_mapa.items()]
plt.legend(handles=legenda)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('medicao_nivel.csv')

# %%
# Mapeamento de cores
cor_mapa = {
    'NORMAL': 'green',
    'ALERTA_Pre_falha': 'orange',
    'FALHA_CRITICA': 'red'
}

cores = df['Status'].map(cor_mapa)

# Gráfico de barras
plt.figure(figsize=(16, 6))
plt.bar(df['ID'], df['Nivel_cm'], color=cores, width=0.5)

plt.xlabel('Medições')
plt.ylabel('Nível de enchimento')
plt.title('Nível de enchimento por status ao longo das medições')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Legenda
import matplotlib.patches as mpatches
legenda = [mpatches.Patch(color=v, label=k) for k, v in cor_mapa.items()]
plt.legend(handles=legenda)

plt.tight_layout()
plt.show()
